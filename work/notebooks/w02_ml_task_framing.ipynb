# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakir-Raza/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Shakir-Raza/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# This project is a ranking problem because the goal is to order webpages by how likely they are to be declining in search performance. Instead of predicting a simple yes/no label, the model ranks pages so that the most important pages appear at the top for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
task_type = "Ranking"
print(task_type)
# Out:
# Ranking

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# Since future performance cannot be known immediately, the model learns from historical search data. The training labels are created from observed search performance over time, making this a supervised learning problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
target = "decline_label"
print(target)
# Out:
# decline_label

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# The primary evaluation metric is Precision@50.
#
# Precision@50 measures how many of the top 50 webpages recommended by the model are actually declining pages.
#
# This metric is appropriate because reviewers usually inspect only a limited number of pages. I also verified that improvements in Precision@50 reflected genuinely better rankings instead of simply a higher metric value.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
metric = "Precision@50"
print(metric)
# Out:
# Precision@50

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# Each row in the dataframe represents one webpage.
#
# Example columns include:
#
# - page_id
# - url
# - impressions
# - clicks
# - ctr
# - average_position
# - search_trend
# - decline_label
#
# The model uses these features to determine how highly each webpage should be ranked for refresh review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

sample = pd.DataFrame({
    "page_id":[1,2],
    "url":["page1","page2"],
    "impressions":[1200,900],
    "clicks":[50,32],
    "decline_label":[1,0]
})

sample
# Out:
#    page_id    url  impressions  clicks  decline_label
# 0        1  page1         1200      50              1
# 1        2  page2          900      32              0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A fixed rule such as refreshing every page with a drop in clicks cannot capture the complex relationships between impressions, clicks, click-through rate, ranking position, and historical trends.
#
# Machine learning can learn these patterns from data and rank webpages more accurately than a single manually designed rule.
#
# This helps reviewers focus on the pages that genuinely need attention instead of relying on simple thresholds.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

reason = "Machine learning combines multiple signals to rank pages more accurately than a fixed rule."
print(reason)
# Out:
# Machine learning combines multiple signals to rank pages more accurately than a fixed rule.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
